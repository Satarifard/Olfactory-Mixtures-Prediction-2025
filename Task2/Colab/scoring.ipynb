# %%
import matplotlib.pyplot as plt

# Using sklearn.model_selection.ShuffleSplit(n_splits=N_SPLITS, random_state=42, test_size=.25)

scores = {"Xuebo":(.22,0.653),
          "LR-Pre-Embed":(.038,0.958),
          "LR-Pos":(.037,0.950), # Using Pretrained-Embed
          "RF-Pre-Embed":(.034,0.960), # Same for RF-Pre-Logits and roughly same with Similarity
          "LR-Pre-Logits":(.041,0.954),
          "LR-Sim-Embed":(.039,0.957),
          "Probabilty":(0.040,0.956),
          }

plt.figure(figsize=(6,6))

for label, (x,y) in scores.items():
    if label == "Xuebo":
        continue
    plt.scatter(x,y,s=50,label=label)
    plt.text(x,y,label,fontsize=6)
    
plt.ylabel("Pearson Correlation ->")
plt.xlabel("<- Cosine Distance")
plt.legend()
plt.tight_layout()
plt.show()
