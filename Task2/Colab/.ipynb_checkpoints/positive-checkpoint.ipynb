# %%
import os

os.chdir("..")

# %%
DATA_DIR = "Data"
fnames = os.listdir(DATA_DIR)
fnames
# Out:
# ['TASK2_Stimulus_definition.csv',
#  'TASK2_Component_definition.csv',
#  'TASK2_Leaderboard_set_Submission_form.csv',
#  'Task2_single_RATA.csv',
#  'manifest.csv',
#  'TASK2_Train_mixture_Dataset.csv',
#  'TASK2_Test_set_Submission_form.csv',
#  'CID.csv']

# %%
import pandas as pd

for fname in fnames:
  print(fname)
  display(pd.read_csv(os.path.join(DATA_DIR,fname)))
  print()
# Out:
# TASK2_Stimulus_definition.csv
#         id components
# 0      166        121
# 1      180        412
# 2      199        442
# 3      204        345
# 4      375        133
# ...    ...        ...
# 1040  L218         76
# 1041  L411        476
# 1042  L788        110
# 1043  L824        306
# 1044  L973        288
#
# [1045 rows x 2 columns]
# TASK2_Component_definition.csv
#       id    CID  dilution solvent
# 0      1     -1      1.00      nt
# 1      2     -2      0.10      pg
# 2      3     -3      0.50      pg
# 3      4     -4      1.00      nt
# 4      5     -5      1.00      nt
# ..   ...    ...       ...     ...
# 526  527  91497      1.00      nt
# 527  528   9261      0.10      pg
# 528  529  92844      0.20      pg
# 529  530  93009      0.01      pg
# 530  531   9589      0.20      pg
#
# [531 rows x 4 columns]
# TASK2_Leaderboard_set_Submission_form.csv
#     stimulus  Green  Cucumber  Herbal  Mint  Woody  Pine  Floral  Powdery  \
# ...

# %% [markdown]
# The files of interest to us are
#
# * `CID.csv` - Data for each molecule (molecule_id, CID, SMILES)
# * `TASK2_Component_definition.csv` - Data for each component by component_id
# * `TASK2_Stimulus_definition.csv` - Data for each stimulus (components by component_id)
# * `TASK2_Train_mixture_Dataset.csv` - Stimuli and their labels
# * `TASK2_Test_set_Submission_form.csv` - Stimuli for test set
# * `TASK2_Leaderboard_set_Submission_form.csv` - Stimuli for leaderboard set

# %% [markdown]
# ### Load in all the definitions.
# So that we can map stimuli labels to the SMILES of the components

# %%
# For some reason the SMILES have unicode symbols. Let's fix those.
def decode_unicode_escapes(smiles: str) -> str:
    return smiles.replace('\xa0', ' ')

cid_df = pd.read_csv(os.path.join(DATA_DIR,"CID.csv"))
cid_df = cid_df[cid_df['is_solvent']=="FALSE"].drop(columns="is_solvent")
cid_df["SMILES"] = cid_df["SMILES"].apply(decode_unicode_escapes)

print("NaN Molecules:", cid_df["SMILES"].isna().sum())
display(cid_df[cid_df["SMILES"].isna()])
print()

cid_to_smiles = cid_df.set_index("molecule")["SMILES"].to_dict()
len(cid_to_smiles), next(iter(cid_to_smiles.items()))
# Out:
# NaN Molecules: 0
# Empty DataFrame
# Columns: [molecule, SMILES]
# Index: []
# (209, (10313079, 'CN(C)C.Cl'))

# %% [markdown]
# Sanity check we can parse everything.

# %%
import rdkit

for smiles in cid_to_smiles.values():
  mol = rdkit.Chem.MolFromSmiles(smiles, sanitize=False)
  assert mol is not None, f"{smiles} is malformed"

# %% [markdown]
# Great! Continue reading in metadata.

# %%
component_df = pd.read_csv(os.path.join(DATA_DIR,"TASK2_Component_definition.csv"))
component_df["SMILES"] = component_df["CID"].map(cid_to_smiles)
print("NaN Components:", component_df["SMILES"].isna().sum())
display(component_df[component_df["SMILES"].isna()])
print()
component_to_smiles = component_df.set_index("id")["SMILES"].to_dict()
type(next(iter(component_to_smiles.keys()))), len(component_to_smiles), next(iter(component_to_smiles.items()))
# Out:
# NaN Components: 32
#       id      CID  dilution       solvent SMILES
# 0      1       -1    1.0000            nt    NaN
# 1      2       -2    0.1000            pg    NaN
# 2      3       -3    0.5000            pg    NaN
# 3      4       -4    1.0000            nt    NaN
# 4      5       -5    1.0000            nt    NaN
# 5      6       -6    1.0000            nt    NaN
# 6      7       -7    1.0000            nt    NaN
# 7      8       -8    1.0000            nt    NaN
# 8      9       -9    1.0000            nt    NaN
# 9     10   102861    0.0100            pg    NaN
# 50    51    10947    0.1000           dep    NaN
# 51    52    10976    0.1000            pg    NaN
# 67    68    11684    0.2000            pg    NaN
# 73    74     1183    0.1000   99% ethanol    NaN
# 91    92    12587    1.0000            nt    NaN
# 136  137    21059    0.0100   90% ethanol    NaN
# 138  139    21648    0.1000   99% ethanol    NaN
# 177  178    31266    0.5000            pg    NaN
# ...

# %% [markdown]
# We have some missing. Let's display.

# %%
component_df[component_df["SMILES"].isna()]["CID"].tolist()
# Out:
# [-1,
#  -2,
#  -3,
#  -4,
#  -5,
#  -6,
#  -7,
#  -8,
#  -9,
#  102861,
#  10947,
#  10976,
#  11684,
#  1183,
#  12587,
#  21059,
#  21648,
#  31266,
#  5144,
#  6054,
#  60985,
#  637563,
#  637563,
#  637563,
#  637563,
#  6429343,
#  6501,
#  7601,
#  7755,
#  7802,
#  8314,
#  8363]

# %%
stimulus_df = pd.read_csv(os.path.join(DATA_DIR,"TASK2_Stimulus_definition.csv"))
stimulus_df["components"] = stimulus_df["components"].apply(lambda cs: cs.split(";"))
stimulus_df["components_SMILES"] = stimulus_df["components"].apply(lambda cs: [component_to_smiles[int(c)] for c in cs])
stimuli_to_components = stimulus_df.set_index("id")["components_SMILES"].to_dict()
len(stimuli_to_components), next(iter(stimuli_to_components.items()))
# Out:
# (1045, ('166', ['C=CCSSCC=C']))

# %% [markdown]
# ### Load in training data.

# %%
train_data_df = pd.read_csv(os.path.join(DATA_DIR,"TASK2_Train_mixture_Dataset.csv"))
train_data_df["components_SMILES"] = train_data_df["stimulus"].map(stimuli_to_components)
train_data_df
# Out:
#     stimulus  Intensity  Pleasantness     Green  Cucumber    Herbal      Mint  \
# 0      AA007   3.888462      5.650000  0.653846  2.807692  0.076923  0.038462
# 1      AA085   7.653846      4.765385  0.076923  0.000000  0.692308  0.730769
# 2      AA088   6.111538      4.261538  0.884615  0.038462  0.692308  0.115385
# 3      AA097   6.246154      6.411538  0.307692  2.538462  0.076923  0.192308
# 4      AA142   6.430769      4.923077  0.076923  0.000000  0.038462  0.000000
# ..       ...        ...           ...       ...       ...       ...       ...
# 388    AI453   5.707143      5.703571  0.000000  0.000000  0.392857  0.035714
# 389    AI665   4.403571      5.289286  0.250000  0.035714  0.214286  0.071429
# 390    AI681   5.525000      5.235714  0.000000  0.071429  0.107143  0.107143
# 391    AI768   5.379310      5.241379  0.275862  0.034483  0.620690  0.206897
# 392    AI780   5.860714      5.457143  0.142857  0.000000  0.178571  0.000000
#
# ...

# %% [markdown]
# Quick analysis across descriptors

# %%
import matplotlib.pyplot as plt

SPECIAL_COLS = ["Intensity","Pleasantness"]

desc_cols = [c for c in train_data_df.columns if not c in {"stimulus","components_SMILES"}]

print(f"Number of Descriptor Columns = {len(desc_cols)}")
for c in desc_cols:
  if c in SPECIAL_COLS:
    train_data_df[c].hist(label=c,alpha=.8)
  else:
    train_data_df[c].hist(alpha=.5)
plt.title("Descriptor Distributions")
plt.legend()
plt.show()
# Out:
# Number of Descriptor Columns = 53

# %%
train_data_df[desc_cols].min(axis=0)
# Out:
# Intensity       1.86
# Pleasantness    1.85
# Green           0.00
# Cucumber        0.00
# Herbal          0.00
# Mint            0.00
# Woody           0.00
# Pine            0.00
# Floral          0.00
# Powdery         0.00
# Fruity          0.00
# Citrus          0.00
# Tropical        0.00
# Berry           0.00
# Peach           0.00
# Sweet           0.00
# Caramellic      0.00
# Vanilla         0.00
# BrownSpice      0.00
# Smoky           0.00
# Burnt           0.00
# Roasted         0.00
# Grainy          0.00
# Meaty           0.00
# Nutty           0.00
# Fatty           0.00
# Coconut         0.00
# Waxy            0.00
# Dairy           0.00
# Buttery         0.00
# Cheesy          0.00
# Sour            0.00
# Fermented       0.00
# Sulfurous       0.00
# Garlic.Onion    0.00
# Earthy          0.00
# Mushroom        0.00
# Musty           0.00
# Ammonia         0.00
# Fishy           0.00
# Fecal           0.00
# Rotten.Decay    0.00
# Rubber          0.00
# ...

# %% [markdown]
# One thing to note is that 'Intensity' and 'Pleasantness' are normally distributed whereas the others seem to be something like a Poisson distribution.

# %% [markdown]
# ### Temporary Fix: Drop the columns for which we don't all the smiles

# %%
train_data_df["is_invalid"] = train_data_df["components_SMILES"].apply(lambda cs: any([pd.isna(s) for s in cs]))
train_data_df = train_data_df[~train_data_df["is_invalid"]].copy()
len(train_data_df)
# Out:
# 392

# %% [markdown]
# ### Load in model and embed mixtures
# We will just try linear regression for now.

# %%
import sys
sys.path.append("dream")

# %%
import dream.production

DEVICE = 'cpu'

graph_model, config = dream.production.load_pretrained(DEVICE)
graph_model.eval()
graph_model
# Out:
# /Users/laurasisson/miniconda3/envs/rdenv/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# GCN(
#   (feature_norm): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (project_node_feats): Sequential(
#     (0): Linear(in_features=9, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.04808747892762695, inplace=False)
#   )
#   (convs): ModuleList(
#     (0-2): 3 x GINConv(nn=Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#     ))
#   )
#   (norms): ModuleList(
# ...

# %% [markdown]
# Let's check real quick which descriptors we don't have

# %%
covered_notes = config["covered_notes"]
{c.lower() for c in desc_cols}.difference(set(covered_notes))
# Out:
# {'ammonia',
#  'brownspice',
#  'chlorine',
#  'cucumber',
#  'fecal',
#  'garlic.onion',
#  'grainy',
#  'intensity',
#  'mint',
#  'ozone',
#  'pleasantness',
#  'rotten.decay',
#  'rubber',
#  'sharp'}

# %% [markdown]
# ### Not bad! As a second pass, we could just recompute only those?

# %%
from tqdm.notebook import tqdm
from ogb.utils import smiles2graph
import dream.pairdata

graph_data = dict()
errored = 0

# Compute individual graphs for all unique SMILES
for smiles in tqdm(cid_to_smiles.values(), desc="Processing SMILES to graphs"):
    try:
        graph_data[smiles] = dream.pairdata.to_torch(smiles2graph(smiles))
    except AttributeError as e:
        print(f"Error processing SMILES: {smiles}. Error: {e}")
        errored += 1
    except TypeError as e:
        print(f"Error processing SMILES: {smiles}. Error: {e}")
        errored += 1

f"Errored smiles: {errored}"
# Out:
# Processing SMILES to graphs:   0%|          | 0/209 [00:00<?, ?it/s]
# 'Errored smiles: 0'

# %%
import dream.data
import time
from torch_geometric.data import Batch
from scipy.spatial import distance
import torch


def _embed(graph,normalize=False):
  with torch.no_grad():
    embedding = graph_model(graph.to(DEVICE))["embed"].cpu().squeeze()

  if normalize:
    return embedding/torch.norm(embedding,dim=-1,keepdim=True)

  return embedding

def make_embedding(blend_smiles,normalize=False):
  assert len(blend_smiles) == len(set(blend_smiles)), blend_smiles
  # For consistency, sort the smiles in the blend.
  blend_smiles = sorted(blend_smiles)
  graphs = [graph_data[smiles] for smiles in blend_smiles]
  blend_data = dream.data.combine_graphs(graphs)
  return _embed(blend_data,normalize)

ex_components = train_data_df["components_SMILES"][0]
ex_components, make_embedding(ex_components).shape
# Out:
# (['CC/C=C\\CCCCC=O', 'CC1COCC2=CC3=C(C=C12)C(C(C3(C)C)C)(C)C'],
#  torch.Size([128]))

# %%
tqdm.pandas(smoothing=0)
train_data_df["embed"] = train_data_df["components_SMILES"].progress_apply(make_embedding)
# Out:
#   0%|          | 0/392 [00:00<?, ?it/s]

# %% [markdown]
# Let's also stack the descriptors into a single array

# %%
import numpy as np
# Let's also stack y
train_data_df["descs"] = train_data_df.apply(lambda r: np.array(r[desc_cols]).astype(float), axis=1)
train_data_df["descs"][0].shape
# Out:
# (53,)

# %% [markdown]
# Let's do a quick 3-fold validation.

# %%
import sklearn
import sklearn.model_selection

import sklearn.linear_model

from scipy.spatial.distance import cosine
from scipy.stats import pearsonr
import numpy as np

def get_xy(df):
    return np.stack(df["embed"].values), np.stack(df["descs"].values)

def score(y_true, y_pred):
    cosine_dist = np.mean([cosine(u, v) for u, v in zip(y_true, y_pred)])
    pearsons = np.mean([pearsonr(u, v)[0] for u, v in zip(y_true, y_pred)])
    return [cosine_dist, pearsons]

N_SPLITS = 5

sss = sklearn.model_selection.ShuffleSplit(n_splits=N_SPLITS, random_state=42, test_size=.25)
scores = []

def make_error_chart(y,pred):
    ty = y.flatten()
    tp = pred.flatten()
    error = ty - tp

    plt.scatter(ty,tp,s=abs(error),c=np.where(error > 0, "C0", "C1"))
    plt.xlabel("Experimental")
    plt.ylabel("Predicted")
    
    csn, prsn = score(y, pred)
    plt.title(f"Absolute Error: (mu = {error.mean():.3f})\nScore: {csn:.3f}, {prsn:.3f}")
    plt.show()
    

for train_index, test_index in tqdm(sss.split(train_data_df), total=N_SPLITS):
    train_df, test_df = train_data_df.iloc[train_index], train_data_df.iloc[test_index]

    train_x, train_y = get_xy(train_df)
    test_x, test_y = get_xy(test_df)


    model = sklearn.linear_model.LinearRegression(positive=True).fit(train_x,train_y)
    test_pred = model.predict(test_x)
    test_pred = np.where(test_pred > 0, test_pred, 0)
    
    make_error_chart(test_y,test_pred)

    scores.append(score(test_y, test_pred))

scores = np.stack(scores).mean(axis=0)
print(f"Cosine: {scores[0]:.3f}\nPearson {scores[1]:.3f}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Cosine: 0.037
# Pearson 0.959

# %% [markdown]
# ### Train final model

# %%
train_data_x, train_data_y = get_xy(train_data_df)

model = sklearn.linear_model.LinearRegression(positive=True).fit(train_data_x,train_data_y)
train_data_pred = model.predict(train_data_x)

model
# Out:
# LinearRegression(positive=True)

# %% [markdown]
# ### Load Leaderboard and Test Data

# %%
test_form_df = pd.read_csv(os.path.join(DATA_DIR,"TASK2_Test_set_Submission_form.csv"))
raw_test_form = test_form_df.copy()

test_form_df["components_SMILES"] = test_form_df["stimulus"].map(stimuli_to_components)
test_form_df["embed"] = test_form_df["components_SMILES"].progress_apply(make_embedding)
display(test_form_df)

leaderboard_form_df = pd.read_csv(os.path.join(DATA_DIR,"TASK2_Leaderboard_set_Submission_form.csv"))
raw_leaderboard_form = leaderboard_form_df.copy()

leaderboard_form_df["components_SMILES"] = leaderboard_form_df["stimulus"].map(stimuli_to_components)
leaderboard_form_df["embed"] = leaderboard_form_df["components_SMILES"].progress_apply(make_embedding)
display(leaderboard_form_df)
# Out:
#   0%|          | 0/130 [00:00<?, ?it/s]
#     stimulus  Green  Cucumber  Herbal  Mint  Woody  Pine  Floral  Powdery  \
# 0      AA322    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# 1      AA374    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# 2      AA444    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# 3      AA524    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# 4      AA616    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# ..       ...    ...       ...     ...   ...    ...   ...     ...      ...
# 125    AP848    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# 126    AQ310    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# 127    AQ862    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# 128    AQ882    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
# 129    AQ810    NaN       NaN     NaN   NaN    NaN   NaN     NaN      NaN
#
# ...

# %%
test_form_x = np.stack(test_form_df["embed"].values)
leaderboard_form_x = np.stack(leaderboard_form_df["embed"].values)

test_form_x.shape, leaderboard_form_x.shape,
# Out:
# ((130, 128), (130, 128))

# %%
test_form_y = model.predict(test_form_x)
leaderboard_form_y = model.predict(leaderboard_form_x)
print("Train", train_data_pred.max(), train_data_pred.min())
print("Test", test_form_y.max(), test_form_y.min())
print("Leaderboard", leaderboard_form_y.max(), leaderboard_form_y.min())

test_form_y.shape, leaderboard_form_y.shape
# Out:
# Train 7.7275257 -0.48843357
# Test 8.479854 -0.5840578
# Leaderboard 8.00155 -0.61002034
# ((130, 53), (130, 53))

# %%
test_form_y = np.where(test_form_y > 0, test_form_y, 0)
leaderboard_form_y = np.where(leaderboard_form_y > 0, test_form_y, 0)

test_form_y.min(), leaderboard_form_y.min()
# Out:
# (0.0, 0.0)

# %%
test_form_df[desc_cols] = test_form_y
test_form_df = test_form_df.drop(columns=["components_SMILES","embed","Intensity","Pleasantness"])
display(test_form_df)

leaderboard_form_df[desc_cols] = leaderboard_form_y
leaderboard_form_df = leaderboard_form_df.drop(columns=["components_SMILES","embed","Intensity","Pleasantness"])
leaderboard_form_df
# Out:
#     stimulus     Green  Cucumber    Herbal      Mint     Woody      Pine  \
# 0      AA322  0.115478  0.000000  0.133148  0.269998  0.233051  0.050071
# 1      AA374  0.346985  0.127937  0.424437  0.000000  0.228359  0.159585
# 2      AA444  0.091018  0.000000  0.080760  0.420414  0.090483  0.003764
# 3      AA524  0.545854  0.070678  0.637252  0.166604  0.401578  0.194853
# 4      AA616  0.009284  0.000000  0.151290  0.601100  0.200861  0.111059
# ..       ...       ...       ...       ...       ...       ...       ...
# 125    AP848  0.270907  0.006829  0.434867  0.028056  0.377657  0.193467
# 126    AQ310  0.536965  0.087517  0.532291  1.227607  0.364720  0.219714
# 127    AQ862  0.295206  0.000000  0.248236  0.094212  0.291153  0.087626
# 128    AQ882  0.549226  0.122533  0.450829  0.130271  0.402380  0.171839
# 129    AQ810  0.039107  0.000000  0.245821  0.496051  0.222675  0.128507
#
#        Floral   Powdery    Fruity  ...  Phenolic    Animal  Medicinal  \
# ...

# %%
assert raw_leaderboard_form.columns.tolist() == leaderboard_form_df.columns.tolist() and raw_leaderboard_form.index.tolist() == leaderboard_form_df.index.tolist()
assert raw_test_form.columns.tolist() == test_form_df.columns.tolist() and raw_test_form.index.tolist() == test_form_df.index.tolist()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12,5))

for c in desc_cols:
    if c in SPECIAL_COLS:
        continue
    axs[0].hist(leaderboard_form_df[c],alpha=.5)
axs[0].set_title("Leaderboard Descriptor Distribution")

for c in desc_cols:
    if c in SPECIAL_COLS:
        continue
    axs[1].hist(leaderboard_form_df[c],alpha=.5)
axs[1].set_title("Test Descriptor Distribution")
plt.show()

# %%
OUTPUT_DIR = "Output/Positive"

# assert input(f"Overwrite {OUTPUT_DIR}") == "y"
# os.mkdir(OUTPUT_DIR)

test_form_df.to_csv(os.path.join(OUTPUT_DIR,"TASK2_Test_set_Submission_form.csv"))
leaderboard_form_df.to_csv(os.path.join(OUTPUT_DIR,"TASK2_Leaderboard_set_Submission_form.csv"))
print("DONE!")
# Out:
# DONE!
